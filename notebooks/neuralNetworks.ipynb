# %% [markdown]
# Y is the ground route
# X is the input
# y is predicted output
# x is intermediate state
#
# One layer y = mX+c
# Error would be Y - y
# To update weight, m = m_previous + k*error , k is learning rate
# assume error has increased, i.e. y is very small, weight should also inrease.
#
# two layers
# y1 = m1X + c1
# y2 = m2(y1) + c2 (input is y1)
# y2 = m2(m1X + c1) + c2
# = m2m1X + m2c1 + c2 = linear equaton.
# -> Add activation layer = add none linearity to linear equation
# y = mx+c => complex
# y1 = activation_function(y1) causing it to be a non linear number
# y2 = m2y1 + c2 => becomes hard to say this is linear function
